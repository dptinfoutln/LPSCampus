# %% [markdown]
# ## Etude de modèles à utiliser pour le Projet LocalPositioningSystem

# %%
import os

import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Récupération des données

# %%
data = []
data_U = []
content_U001 = open("./Scan/Train/U-001.txt", "r")

# %%
content_U001.read()
# Out:
# 'scan:2021-04-08_15-44-14\ninfos:Centre\nBSSID:1c:28:af:ce:1b:d0\nCapabilities:[WPA2-EAP-CCMP][WPA-EAP-TKIP+CCMP][ESS]\nCenterFreq0:0\nCenterFreq1:0\nChannelWidth:0\nFrequency:5220\nLevel:-30\nOperatorFriendlyName:\nSSID:eduroam\nTimestamp:743871886320\nVenueName:\n\nBSSID:1c:28:af:ce:1b:d1\nCapabilities:[WPA2-EAP+FT/EAP-CCMP][WPA-EAP-TKIP][ESS]\nCenterFreq0:0\nCenterFreq1:0\nChannelWidth:0\nFrequency:5220\nLevel:-30\nOperatorFriendlyName:\nSSID:UnivToulon\nTimestamp:743871886934\nVenueName:\n\nBSSID:1c:28:af:ce:1b:d2\nCapabilities:[ESS]\nCenterFreq0:0\nCenterFreq1:0\nChannelWidth:0\nFrequency:5220\nLevel:-30\nOperatorFriendlyName:\nSSID:visiteurs\nTimestamp:743871887150\nVenueName:\n\nBSSID:1c:28:af:ce:1b:d3\nCapabilities:[ESS]\nCenterFreq0:0\nCenterFreq1:0\nChannelWidth:0\nFrequency:5220\nLevel:-30\nOperatorFriendlyName:\nSSID:\nTimestamp:743871857830\nVenueName:\n\nBSSID:1c:28:af:ce:1b:d4\nCapabilities:[ESS]\nCenterFreq0:0\nCenterFreq1:0\nChannelWidth:0\nFrequency:5220\nLevel:-30\nOperatorFriendlyName:\nSSID:\nTimestamp:743871858084\nVenueName:\n\nBSSID:0c:e4:a0:0e:22:3c\nCapabilities:[WPA2-PSK-CCMP][ESS]\nCenterFreq0:0\nCenterFreq1:0\nChannelWidth:0\nFrequency:2412\nLevel:-42\nOperatorFriendlyName:\nSSID:HUAWEI P smart\nTimestamp:743871370133\nVenueName:\n\nBSSID:1c:28:af:ce:1b:c0\nCapabilities:[WPA2-EAP-CCMP][WPA-EAP-TKIP+CCMP][ESS]\nCenterFreq0:0\nCenterFreq1:0\nChannelWidth:0\nFrequency:2412\nLevel:-45\nOperatorFriendlyName:\nSSID:eduroam\nTimestamp:743871367875\nVenueName:\n\nBSSID:1c:28:af:ce:1b:c1\nCapabilities:[WPA2-EAP+FT/EAP-CCMP][WPA-EAP-TKIP][ESS]\nCenterFreq0:0\nCenterFreq1:0\nChannelWidth:0\nFrequency:2412\nLevel:-45\nOperatorFriendlyName:\nSSID:UnivToulon\nTimestamp:743871373584\nVenueName:\n\nBSSID:1c:28:af:ce:1b:c2\nCapabilities:[ESS]\nCenterFreq0:0\nCenterFreq1:0\nChannelWidth:0\nFrequency:2412\nLevel:-45\nOperatorFriendlyName:\nSSID:visiteurs\nTimestamp:743871376665\nVenueName:\n\nBSSID:1c:28:af:b4:1c:e1\nCapabilities:[WPA2-EAP+FT/EAP-CCMP][WPA-EAP-TKIP][ESS]\nCenterFreq0:0\nCenterFreq1:0\nChannelWidth:0\nFrequency:2462\nLevel:-59\nOperatorFriendlyName:\nSSID:UnivToulon\nTimestamp:743871555826\nVenueName:\n\nBSSID:1c:28:af:ce:e7:00\nCapabilities:[WPA2-EAP-CCMP][WPA-EAP-TKIP+CCMP][ESS]\nCenterFreq0:0\nCenterFreq1:0\nChannelWidth:0\nFrequency:2437\nLevel:-59\nOperatorFriendlyName:\nSSID:eduroam\nTimestamp:743871494164\nVenueName:\n\nBSSID:1c:28:af:ce:e7:01\nCapabilities:[WPA2-EAP+FT/EAP-CCMP][WPA-EAP-TKIP][ESS]\nCenterFreq0:0\nCenterFreq1:0\nChannelWidth:0\nFrequency:2437\nLevel:-59\nOperatorFriendlyName:\nSSID:UnivToulon\nTimestamp:743871498160\nVenueName:\n\nBSSID:1c:28:af:b4:1c:e0\nCapabilities:[WPA2-EAP-CCMP][WPA-EAP-TKIP+CCMP][ESS]\nCenterFreq0:0\nCenterFreq1:0\nChannelWidth:0\nFrequency:2462\nLevel:-59\nOperatorFriendlyName:\nSSID:eduroam\nTimestamp:743871552763\nVenueName:\n\nBSSID:1c:28:af:b4:1c:e3\nCapabilities:[ESS]\nCenterFreq0:0\nCenterFreq1:0\nChannelWidth:0\nFrequency:2462\nLevel:-59\nOperatorFriendlyName:\nSSID:\nTimestamp:743871561389\nVenueName:\n\nBSSID:1c:28:af:ce:e7:02\nCapabilities:[ESS]\nCenterFreq0:0\nCenterFreq1:0\nChannelWidth:0\nFrequency:2437\nLevel:-60\nOperatorFriendlyName:\nSSID:visiteurs\nTimestamp:743871475466\nVenueName:\n\nBSSID:1c:28:af:b4:1c:e2\nCapabilities:[ESS]\nCenterFreq0:0\nCenterFreq1:0\nChannelWidth:0\nFrequency:2462\nLevel:-60\nOperatorFriendlyName:\nSSID:visiteurs\nTimestamp:743871558412\nVenueName:\n\nBSSID:1c:28:af:b2:c8:50\nCapabilities:[WPA2-EAP-CCMP][WPA-EAP-TKIP+CCMP][ESS]\nCenterFreq0:0\nCenterFreq1:0\nChannelWidth:0\nFrequency:5580\nLevel:-66\nOperatorFriendlyName:\nSSID:eduroam\nTimestamp:743872966569\nVenueName:\n\nBSSID:1c:28:af:b2:c8:51\nCapabilities:[WPA2-EAP+FT/EAP-CCMP][WPA-EAP-TKIP][ESS]\nCenterFreq0:0\nCenterFreq1:0\nChannelWidth:0\nFrequency:5580\nLevel:-67\nOperatorFriendlyName:\nSSID:UnivToulon\nTimestamp:743872960477\nVenueName:\n\nBSSID:1c:28:af:b2:c8:52\nCapabilities:[ESS]\nCenterFreq0:0\nCenterFreq1:0\nChannelWidth:0\nFrequency:5580\nLeve ...

# %%
### COMMON ###

def enlever_extension(nom):
    return ".".join(nom.split(".")[:-1])

# %%
class Wifi:
    def __init__(self, BSSID, capabilities, centerFreq0, centerFreq1,
                 channelWidth, frequency, level, operatorFriendlyName, SSID,
                 timestamp, venueName):
        self.BSSID = BSSID
        self.capabilities = capabilities
        self.centerFreq0 = centerFreq0
        self.centerFreq1 = centerFreq1
        self.channelWidth = channelWidth
        self.frequency = frequency
        self.level = level
        self.operatorFriendlyName = operatorFriendlyName
        self.SSID = SSID
        self.timestamp = timestamp
        self.venueName = venueName

class Scan:
    def __init__(self, date, info, piece, lWifi):
        self.date = date
        self.info = info
        self.piece = piece
        self.lWifi = lWifi

class ScanManager:
    def __init__(self):
        self.lScan = []
    
    def read(self, directory="./Scan/Train/"):
        # pour chaque fichier dans le dossier
        for fname in os.listdir(directory):
            with open(directory + fname) as fichier:
                # la piece est donnée par le nom du fichier
                piece = enlever_extension(fname)
                
                # Separation des scans
                for scanData in fichier.read().split("scan")[1:]:
                    
                    scan_lines = scanData.splitlines()
                    scanDate = scan_lines[0].split(":")[1]
                    scanInfo = scan_lines[1].split(":")[1]
                    scanWifis = []

                    wifis_content = scan_lines[2:]

                    # Separation des wifis detectes sur le scan
                    wifis_list = [wifis_content[x:x+11] for x in range(0, len(wifis_content), 12)][:-1]
                    
                    for wifi_car_l in (wifis_list) :
                        wifiBSSID = wifi_car_l[0].split("BSSID:")[1] 
                        cap = wifi_car_l[1].split(":")[1]
                        freq0 = int(wifi_car_l[2].split(":")[1])
                        freq1 = int(wifi_car_l[3].split(":")[1])
                        cWidth = int(wifi_car_l[4].split(":")[1])
                        freq = int(wifi_car_l[5].split(":")[1])
                        level = int(wifi_car_l[6].split(":")[1])
                        op_name = wifi_car_l[7].split(":")[1]
                        ssid = wifi_car_l[8].split(":")[1]
                        ts = int(wifi_car_l[9].split(":")[1])
                        vn = wifi_car_l[10].split(":")[1]                            
                            
                        wifi = Wifi(wifiBSSID, cap, freq0, freq1, cWidth, freq, level, op_name, ssid,ts, vn)
                        scanWifis.append(wifi)
                    scan = Scan(scanDate, scanInfo, piece, scanWifis)
                    self.lScan.append(scan)


def get_salle_data(scan_salle_file = "U-001.txt"):
    path_scan = "./Scan/Train/" + scan_salle_file
    file_scans = open(path_scan, "r")
    content_scans = file_scans.read()
    file_scans.close()
    
    scans = {}
    
    scans_list = content_scans.split("scan")[1:]
 
    #Separation des scans
    for scan in scans_list :
        
        scan_lines = scan.splitlines()
        scanDate = scan_lines[0].split(":")[1]
        scanInfo = scan_lines[1].split(":")[1]

        wifis_content = scan_lines[2:]
        scans[scanDate] = wifis_content
        #print(scans["2021-04-08_15-44-14"])
       
        # Separation des wifis detectes sur le scan
        wifis_list = [wifis_content[x:x+11] for x in range(0, len(wifis_content), 12)][:-1]

        
    print(wifis_list[-1])
    print(wifis_list[-1][0].split("BSSID:")[1])
    #print(scans_list[0])
    #print(wifis_list[-1])
get_salle_data()





s_man = ScanManager()
# Out:
# ['BSSID:1c:28:af:cd:9f:70', 'Capabilities:[WPA2-EAP-CCMP][WPA-EAP-TKIP+CCMP][ESS]', 'CenterFreq0:0', 'CenterFreq1:0', 'ChannelWidth:0', 'Frequency:5260', 'Level:-87', 'OperatorFriendlyName:', 'SSID:eduroam', 'Timestamp:744151659936', 'VenueName:']
# 1c:28:af:cd:9f:70

# %% [markdown]
# ### Correlations

# %%
def get_data_csv(scanMan):
    dico = {}
    dico["BSSID"] = []
    dico["capabilities"] = []
    dico["centerFreq0"] = []
    dico["centerFreq1"] = []
    dico["channelWidth"] = []
    dico["frequency"] = []
    dico["level"] = []
    dico["operatorFriendlyName"] = []
    dico["SSID"] = []
    dico["timestamp"] = []
    dico["venueName"] = []
    dico["piece"] = []
    dico["zone_info"] = []
    dico["date"] = []
    
    for scan in scanMan.lScan :
        for wifi in scan.lWifi:
            dico["piece"].append(scan.piece)
            dico["zone_info"].append(scan.info)
            dico["date"].append(scan.date)
            
            dico["BSSID"].append(wifi.BSSID)
            dico["capabilities"].append(wifi.capabilities)
            dico["centerFreq0"].append(wifi.centerFreq0)
            dico["centerFreq1"].append(wifi.centerFreq1)
            dico["channelWidth"].append(wifi.channelWidth)
            dico["frequency"].append(wifi.frequency)
            dico["level"].append(wifi.level)
            dico["operatorFriendlyName"].append(wifi.operatorFriendlyName)
            dico["SSID"].append(wifi.SSID)
            dico["timestamp"].append(wifi.timestamp)
            dico["venueName"].append(wifi.venueName)
    data_csv = pd.DataFrame.from_dict(dico)
    
    return data_csv

# %%
scanMan = ScanManager()
scanMan.read()
all_data_csv = get_data_csv(scanMan)
all_data_csv.head()
# Out:
#                BSSID                               capabilities  centerFreq0  \
# 0  1c:28:af:ce:1b:d0    [WPA2-EAP-CCMP][WPA-EAP-TKIP+CCMP][ESS]            0
# 1  1c:28:af:ce:1b:d1  [WPA2-EAP+FT/EAP-CCMP][WPA-EAP-TKIP][ESS]            0
# 2  1c:28:af:ce:1b:d2                                      [ESS]            0
# 3  1c:28:af:ce:1b:d3                                      [ESS]            0
# 4  1c:28:af:ce:1b:d4                                      [ESS]            0
#
#    centerFreq1  channelWidth  frequency  level operatorFriendlyName  \
# 0            0             0       5220    -44
# 1            0             0       5220    -44
# 2            0             0       5220    -44
# 3            0             0       5220    -44
# 4            0             0       5220    -44
#
#          SSID     timestamp venueName  piece zone_info                 date
# 0     eduroam  744453009082            U-004    Centre  2021-04-08_15-56-33
# 1  UnivToulon  744453009726            U-004    Centre  2021-04-08_15-56-33
# 2   visiteurs  744453010077            U-004    Centre  2021-04-08_15-56-33
# 3              744452981219            U-004    Centre  2021-04-08_15-56-33
# 4              744452981590            U-004    Centre  2021-04-08_15-56-33

# %%
def data_organizer(scanMan, car = 'level'):
    
    all_data_csv = get_data_csv(scanMan)

    data_csv = all_data_csv[ ['BSSID', 'piece', car] ]
    data_csv = data_csv.pivot_table(data_csv,
                                    index=['BSSID'],
                                    columns = ['piece'],
                                    aggfunc={car: np.mean},
                                    fill_value=0, 
                                    ob)

      
    return data_csv.astype(int)

def all_data_organizer(scanMan):
    
    all_data_csv = get_data_csv(scanMan)

    data_csv = all_data_csv.pivot_table(all_data_csv,
                                    index=['BSSID'],
                                    columns = ['piece'], 
                                    aggfunc={'level': np.mean,
                                             'frequency': np.mean},
                                    fill_value=0)

    return data_csv.astype(int)

# %%
scanMan = ScanManager()
scanMan.read()
data_csv = data_organizer(scanMan)
data_csv.head()
# Out:
#                   level                                                 \
# piece             U-001 U-004 U-100 U-Administration U-Couloir-001-004
# BSSID
# 0c:e4:a0:0e:22:3c   -39   -60   -80                0               -48
# 1c:28:af:b2:95:a0     0     0     0                0                 0
# 1c:28:af:b2:95:a1     0     0     0                0                 0
# 1c:28:af:b2:95:a2     0     0     0                0                 0
# 1c:28:af:b2:95:a3     0     0     0                0                 0
#
#                                                                       \
# piece             U-Couloir-Entree U-Couloir-Etage1 U-Couloir-Etage2
# BSSID
# 0c:e4:a0:0e:22:3c                0              -71                0
# 1c:28:af:b2:95:a0                0                0              -62
# 1c:28:af:b2:95:a1                0                0              -62
# 1c:28:af:b2:95:a2                0                0              -71
# 1c:28:af:b2:95:a3                0                0              -74
#
#
# piece             U-Couloir-Etage3 U-Couloir-Foyer
# BSSID
# 0c:e4:a0:0e:22:3c                0               0
# 1c:28:af:b2:95:a0              -60               0
# 1c:28:af:b2:95:a1              -58               0
# 1c:28:af:b2:95:a2              -60               0
# 1c:28:af:b2:95:a3                0               0

# %%
data_csv = all_data_organizer(scanMan)
data_csv.head()
# Out:
#                   frequency                                                 \
# piece                 U-001 U-004 U-100 U-Administration U-Couloir-001-004
# BSSID
# 0c:e4:a0:0e:22:3c      2412  2412  2412                0              2412
# 1c:28:af:b2:95:a0         0     0     0                0                 0
# 1c:28:af:b2:95:a1         0     0     0                0                 0
# 1c:28:af:b2:95:a2         0     0     0                0                 0
# 1c:28:af:b2:95:a3         0     0     0                0                 0
#
#                                                                       \
# piece             U-Couloir-Entree U-Couloir-Etage1 U-Couloir-Etage2
# BSSID
# 0c:e4:a0:0e:22:3c                0             2412                0
# 1c:28:af:b2:95:a0                0                0             2462
# 1c:28:af:b2:95:a1                0                0             2462
# 1c:28:af:b2:95:a2                0                0             2462
# 1c:28:af:b2:95:a3                0                0             2462
#
#                                                    level              \
# piece             U-Couloir-Etage3 U-Couloir-Foyer U-001 U-004 U-100
# BSSID
# 0c:e4:a0:0e:22:3c                0               0   -39   -60   -80
# 1c:28:af:b2:95:a0             2462               0     0     0     0
# 1c:28:af:b2:95:a1             2462               0     0     0     0
# 1c:28:af:b2:95:a2             2462               0     0     0     0
# 1c:28:af:b2:95:a3                0               0     0     0     0
#
#                                                                        \
# piece             U-Administration U-Couloir-001-004 U-Couloir-Entree
# BSSID
# 0c:e4:a0:0e:22:3c                0               -48                0
# 1c:28:af:b2:95:a0                0                 0                0
# 1c:28:af:b2:95:a1                0                 0                0
# 1c:28:af:b2:95:a2                0                 0                0
# 1c:28:af:b2:95:a3                0                 0                0
#
#                                                                       \
# piece             U-Couloir-Etage1 U-Couloir-Etage2 U-Couloir-Etage3
# BSSID
# 0c:e4:a0:0e:22:3c              -71                0                0
# 1c:28:af:b2:95:a0                0              -62              -60
# 1c:28:af:b2:95:a1                0              -62              -58
# 1c:28:af:b2:95:a2                0              -71              -60
# 1c:28:af:b2:95:a3                0              -74                0
#
#
# piece             U-Couloir-Foyer
# BSSID
# 0c:e4:a0:0e:22:3c               0
# 1c:28:af:b2:95:a0               0
# 1c:28:af:b2:95:a1               0
# 1c:28:af:b2:95:a2               0
# 1c:28:af:b2:95:a3               0

# %%
def calcul_correlation(scanMan):
    """
    Renvoie la corrélation de variables récupérées
    """
    lvl_data = all_data_organizer(scanMan)
    return lvl_data.corr()

# %%
#corr = calcul_correlation(scanMan)

# %%
#sns.heatmap(corr, annot=True, cbar=True, cmap="RdYlGn")

# %%
def get_car_correl_matrixes(scanMan):
    for car in ['level', 'centerFreq0', 'centerFreq1','channelWidth', 'frequency', 'timestamp']:
        car_data_csv = data_organizer(scanMan, car)
        sns.heatmap(car_data_csv.corr(), annot=True, cbar=True, cmap="RdYlGn")
        
        return
get_car_correl_matrixes(scanMan)
